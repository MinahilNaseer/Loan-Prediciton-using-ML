# %%
import pandas as pd

df= pd.read_csv('/loan_pred.csv')

# %%
df.shape
# Out:
# (614, 13)

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

features_to_plot = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount','Loan_Amount_Term','Credit_History']
for feature in features_to_plot:
    plt.figure(figsize=(8, 5))
    sns.boxplot(data=df, x='Loan_Status', y=feature)
    plt.title(f'Box Plot of {feature} by Loan Status')
    plt.xlabel('Loan Status')
    plt.ylabel(feature)
    plt.show()

# %%
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].median())
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
df['Credit_History'].median()
# Out:
# 1.0

# %%
df['Credit_History'].mean()
# Out:
# 0.8421985815602836

# %%
#null values of string data
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df['Gender'].mode()[0]
# Out:
# 'Male'

# %%
df['Married'].mode()[0]
# Out:
# 'Yes'

# %%
df['Dependents'].mode()
# Out:
# 0    0
# Name: Dependents, dtype: object

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
#visulaization
print('Number of people who took loan by gender')
print(df['Gender'].value_counts())
sns.countplot(x='Gender',data=df,palette='Set1')
# Out:
# Number of people who took loan by gender
# Gender
# Male      502
# Female    112
# Name: count, dtype: int64
# <ipython-input-103-6cb969050b3e>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender',data=df,palette='Set1')
# <Axes: xlabel='Gender', ylabel='count'>

# %%
#visulaization
print('Number of people who took loan by gender')
print(df['Married'].value_counts())
sns.countplot(x='Married',data=df,palette='Set1')
# Out:
# Number of people who took loan by gender
# Married
# Yes    401
# No     213
# Name: count, dtype: int64
# <ipython-input-104-64afda672d92>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Married',data=df,palette='Set1')
# <Axes: xlabel='Married', ylabel='count'>

# %%
#visulaization
print('Number of people who took loan by gender')
print(df['Self_Employed'].value_counts())
sns.countplot(x='Self_Employed',data=df,palette='Set1')
# Out:
# Number of people who took loan by gender
# Self_Employed
# No     532
# Yes     82
# Name: count, dtype: int64
# <ipython-input-105-20785bf7b59b>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Self_Employed',data=df,palette='Set1')
# <Axes: xlabel='Self_Employed', ylabel='count'>

# %%
#visulaization
print('Number of people who took loan by gender')
print(df['Loan_Status'].value_counts())
sns.countplot(x='Loan_Status',data=df,palette='Set1')
# Out:
# Number of people who took loan by gender
# Loan_Status
# Y    422
# N    192
# Name: count, dtype: int64
# <ipython-input-106-115536d0e5e3>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Loan_Status',data=df,palette='Set1')
# <Axes: xlabel='Loan_Status', ylabel='count'>

# %%
df.drop('Loan_ID',axis=1,inplace=True)

# %%
#total applicant income to be calculated
df['Total_Applicant_Income'] = df['ApplicantIncome'] + df['CoapplicantIncome']
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0       128.0             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status  Total_Applicant_Income
# 0         Urban           Y                  5849.0
# ...

# %%
sns.distplot(df['ApplicantIncome'])
# Out:
# <ipython-input-109-dd358a5a6987>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ApplicantIncome'])
# <Axes: xlabel='ApplicantIncome', ylabel='Density'>

# %%
#normalizing the distribution

sns.distplot(df['LoanAmount'])
# Out:
# <ipython-input-110-d2cb33f5d91e>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['LoanAmount'])
# <Axes: xlabel='LoanAmount', ylabel='Density'>

# %%
import numpy as np
df['ApplicantIncomelog'] = np.log(df['ApplicantIncome']+1)
sns.distplot(df['ApplicantIncomelog'])
# Out:
# <ipython-input-111-30f682861ef3>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ApplicantIncomelog'])
# <Axes: xlabel='ApplicantIncomelog', ylabel='Density'>

# %%
df['LoanAmountLog'] = np.log(df['LoanAmount']+1)
sns.distplot(df['LoanAmountLog'])
# Out:
# <ipython-input-112-9e7189995229>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['LoanAmountLog'])
# <Axes: xlabel='LoanAmountLog', ylabel='Density'>

# %%
df['Loan_Amount_Term_log'] = np.log(df['Loan_Amount_Term']+1)
sns.distplot(df['Loan_Amount_Term_log'])
# Out:
# <ipython-input-113-c1749fa71ab1>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Loan_Amount_Term_log'])
# <Axes: xlabel='Loan_Amount_Term_log', ylabel='Density'>

# %%
df['Total_Applicant_Income_log'] = np.log(df['Total_Applicant_Income']+1)
sns.distplot(df['Total_Applicant_Income_log'])
# Out:
# <ipython-input-114-f397bf163b0d>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Total_Applicant_Income_log'])
# <Axes: xlabel='Total_Applicant_Income_log', ylabel='Density'>

# %%
df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes         3+      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
#drop the other columns
cols = ['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Total_Applicant_Income']
df.drop(cols,axis=1,inplace=True)

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
#
#   Property_Area Loan_Status  ApplicantIncomelog  LoanAmountLog  \
# 0         Urban           Y            8.674197       4.859812
# 1         Rural           N            8.430327       4.859812
# 2         Urban           Y            8.006701       4.204693
# 3         Urban           Y            7.857094       4.795791
# 4         Urban           Y            8.699681       4.955827
#
#    Loan_Amount_Term_log  Total_Applicant_Income_log
# 0              5.888878                    8.674197
# ...

# %%
#Encoding using Label (Yes/No) and One Hot Enoding (more then 2 or 3)
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer

cols = ['Gender','Married','Dependents','Education','Self_Employed','Property_Area','Loan_Status']
le = LabelEncoder()
for col in cols:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0           0          0              0             1.0
# 1       1        1           1          0              0             1.0
# 2       1        1           0          0              1             1.0
# 3       1        1           0          1              0             1.0
# 4       1        0           0          0              0             1.0
#
#    Property_Area  Loan_Status  ApplicantIncomelog  LoanAmountLog  \
# 0              2            1            8.674197       4.859812
# 1              0            0            8.430327       4.859812
# 2              2            1            8.006701       4.204693
# 3              2            1            7.857094       4.795791
# 4              2            1            8.699681       4.955827
#
#    Loan_Amount_Term_log  Total_Applicant_Income_log
# 0              5.888878                    8.674197
# ...

# %%
df.dtypes
# Out:
# Gender                          int64
# Married                         int64
# Dependents                      int64
# Education                       int64
# Self_Employed                   int64
# Credit_History                float64
# Property_Area                   int64
# Loan_Status                     int64
# ApplicantIncomelog            float64
# LoanAmountLog                 float64
# Loan_Amount_Term_log          float64
# Total_Applicant_Income_log    float64
# dtype: object

# %%
correlation_matrix = df.corr()

plt.figure(figsize=(15, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix of Preprocessed Features')
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier



X = df.drop('Loan_Status',axis=1)
y = df['Loan_Status']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
#using LR
model_LR = LogisticRegression()
model_LR.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model_LR.predict(X_test)


accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.77
#               precision    recall  f1-score   support
#
#            0       0.91      0.39      0.55        54
#            1       0.75      0.98      0.85       100
#
#     accuracy                           0.77       154
#    macro avg       0.83      0.68      0.70       154
# weighted avg       0.81      0.77      0.74       154

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc, precision_recall_curve

y_pred_proba = model_LR.predict_proba(X_test)[:, 1]

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for LR')
plt.show()

# %%
#using DT
model_DT = DecisionTreeClassifier()
model_DT.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model_DT.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.73
#               precision    recall  f1-score   support
#
#            0       0.63      0.57      0.60        54
#            1       0.78      0.82      0.80       100
#
#     accuracy                           0.73       154
#    macro avg       0.71      0.70      0.70       154
# weighted avg       0.73      0.73      0.73       154

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for DT')
plt.show()

# %%
y_pred_proba = model_DT.predict_proba(X_test)[:, 1]

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
#using KNN
model_KNN = KNeighborsClassifier()
model_KNN.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = model_KNN.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.73
#               precision    recall  f1-score   support
#
#            0       0.71      0.37      0.49        54
#            1       0.73      0.92      0.81       100
#
#     accuracy                           0.73       154
#    macro avg       0.72      0.65      0.65       154
# weighted avg       0.72      0.73      0.70       154

# %%
y_pred_proba = model_KNN.predict_proba(X_test)[:, 1]

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for KNN')
plt.show()

# %%
#using RF
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.79
#               precision    recall  f1-score   support
#
#            0       0.89      0.46      0.61        54
#            1       0.77      0.97      0.86       100
#
#     accuracy                           0.79       154
#    macro avg       0.83      0.72      0.73       154
# weighted avg       0.81      0.79      0.77       154

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20, 10))
tree = model.estimators_[0]
plot_tree(tree, feature_names=X.columns, class_names=['No', 'Yes'], filled=True, fontsize=8)
plt.title("Visualization of a Single Decision Tree in the Random Forest")
plt.show()

# %%
y_pred_proba = model.predict_proba(X_test)[:, 1]

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Random Forest')
plt.show()

# %%
df['Loan_Status'].value_counts()
# Out:
# Loan_Status
# 1    422
# 0    192
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)
X_resampled, y_resampled = ros.fit_resample(X, y)


df_resampled = pd.concat([pd.DataFrame(X_resampled, columns=X.columns),pd.Series(y_resampled,name="Loan_Status")], axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:484: FutureWarning: `BaseEstimator._check_n_features` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_n_features` instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: FutureWarning: `BaseEstimator._check_feature_names` is deprecated in 1.6 and will be removed in 1.7. Use `sklearn.utils.validation._check_feature_names` instead.
#   warnings.warn(

# %%
y_resampled.value_counts()
# Out:
# Loan_Status
# 1    422
# 0    422
# Name: count, dtype: int64

# %%
X_resample_train, X_resample_test, y_resample_train, y_resample_test = train_test_split(X_resampled, y_resampled, test_size=0.25, random_state=42)

# %%
model_2 = LogisticRegression()
model_2.fit(X_resample_train, y_resample_train)
y_pred_model_2 = model_2.predict(X_resample_test)
accuracy_model3 = accuracy_score(y_resample_test, y_pred_model_2)
print(f"Accuracy: {accuracy_model3:.2f}")
print(classification_report(y_resample_test, y_pred_model_2))
# Out:
# Accuracy: 0.69
#               precision    recall  f1-score   support
#
#            0       0.84      0.54      0.65       114
#            1       0.62      0.88      0.72        97
#
#     accuracy                           0.69       211
#    macro avg       0.73      0.71      0.69       211
# weighted avg       0.73      0.69      0.69       211

# %%
confusion_matrix_model3 = confusion_matrix(y_resample_test, y_pred_model_2)

plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix_model3, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.title('Confusion Matrix for LR')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
y_pred_proba = model_2.predict_proba(X_test)[:, 1]

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
model3 = RandomForestClassifier()
model3.fit(X_resample_train, y_resample_train)
y_pred_model3 = model3.predict(X_resample_test)
accuracy_model3 = accuracy_score(y_resample_test, y_pred_model3)
print(f"Accuracy: {accuracy_model3:.2f}")
print(classification_report(y_resample_test, y_pred_model3))
# Out:
# Accuracy: 0.89
#               precision    recall  f1-score   support
#
#            0       0.92      0.86      0.89       114
#            1       0.85      0.92      0.88        97
#
#     accuracy                           0.89       211
#    macro avg       0.89      0.89      0.89       211
# weighted avg       0.89      0.89      0.89       211

# %%
confusion_matrix_model3 = confusion_matrix(y_resample_test, y_pred_model3)

plt.figure(figsize=(6, 4))
sns.heatmap(confusion_matrix_model3, annot=True, fmt='d', cmap='Blues', xticklabels=['No', 'Yes'], yticklabels=['No', 'Yes'])
plt.title('Confusion Matrix for Random Forest Classifier')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
y_pred_proba = model3.predict_proba(X_test)[:, 1]

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_pred_proba)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, label=f"ROC curve (AUC = {roc_auc:.2f})")
plt.plot([0, 1], [0, 1], linestyle="--", color="gray")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %%
df_resampled
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0         1        0           0          0              0        1.000000
# 1         1        1           1          0              0        1.000000
# 2         1        1           0          0              1        1.000000
# 3         1        1           0          1              0        1.000000
# 4         1        0           0          0              0        1.000000
# ..      ...      ...         ...        ...            ...             ...
# 839       1        1           3          1              0        1.000000
# 840       1        1           1          0              0        0.842199
# 841       1        1           1          0              0        0.000000
# 842       1        1           2          1              0        0.000000
# 843       1        0           0          0              0        0.000000
#
# ...

# %%
import joblib


#joblib.dump(model, 'Random_Forest_model.pkl')

# %%
from google.colab import files

#files.download('Random_Forest_model.pkl')
